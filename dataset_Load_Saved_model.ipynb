# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/CNN/'
# Out:
# dataset				      Sports_Celebrity_Data
# dataset_Image_Classification.ipynb    Vehicle_Data
# dataset_Load_Saved_model.ipynb	      Vehicle_Trained_Model_S128E25.h5
# dataset_S256E20.h5		      Vehicle_Trained_Model_S256E15.h5
# Image_Classification_using_CNN.ipynb  Vehicle_Trained_Model_S256E25.h5
# Load_Saved_model.ipynb		      Vehicle_Trained_Model_S64E20.h5
# my_model.h5

# %%
model_path = '/content/drive/My Drive/CNN/'

# %%
from tensorflow import keras


model = keras.models.load_model(model_path+'dataset_S256E20.h5')

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Creating dictionaries to map folder names

name_mapping_dict = {'cars': 0,
                     'planes': 1,
                     'trains': 2
                     }


inv_name_mapping_dict =  {v: k for k, v in name_mapping_dict.items()}

print(inv_name_mapping_dict)
# Out:
# {0: 'cars', 1: 'planes', 2: 'trains'}

# %%
img_size = 256

# %%
img = plt.imread('h.jpg')
img = cv2.resize(img, (img_size, img_size))


img.shape
# Out:
# (256, 256, 3)

# %%
temp_img = np.expand_dims(img, axis=0)

temp_img.shape
# Out:
# (1, 256, 256, 3)

# %%
prediction = inv_name_mapping_dict[np.argmax(model.predict(temp_img)[0])]
print("Model prediction: {}".format(prediction))

# Display the predicted image
plt.imshow(img)
plt.show()
# Out:
# Model prediction: planes

# %% [markdown]
# **Lets combine it in a function**

# %%
def test_func(model, img_size, img_name, class_name_mapping):
  img = plt.imread(img_name)
  img = cv2.resize(img, (img_size, img_size))

  temp_img = np.expand_dims(img, axis=0)
  
  prediction = class_name_mapping[np.argmax(model.predict(temp_img)[0])]
  print("Model prediction: {}".format(prediction))
  
  plt.imshow(img)
  plt.show()

# %%
test_func(model, img_size=256, img_name='a.jpg', class_name_mapping=inv_name_mapping_dict)
# Out:
# Model prediction: planes

# %%
test_func(model, img_size=256, img_name='i.jpg', class_name_mapping=inv_name_mapping_dict)
# Out:
# Model prediction: planes

# %%
test_func(model, img_size=256, img_name='j.jpg', class_name_mapping=inv_name_mapping_dict)
# Out:
# Model prediction: cars

# %%
test_func(model, img_size=256, img_name='k.jpg', class_name_mapping=inv_name_mapping_dict)
# Out:
# Model prediction: planes

# %%
test_func(model, img_size=256, img_name='l.jpg', class_name_mapping=inv_name_mapping_dict)
# Out:
# Model prediction: planes

# %%
test_func(model, img_size=256, img_name='m.jpg', class_name_mapping=inv_name_mapping_dict)
# Out:
# Model prediction: planes

# %%
test_func(model, img_size=256, img_name='n.jpg', class_name_mapping=inv_name_mapping_dict)
# Out:
# Model prediction: cars

# %%
test_func(model, img_size=256, img_name='o.jpg', class_name_mapping=inv_name_mapping_dict)
# Out:
# Model prediction: cars

# %%
test_func(model, img_size=256, img_name='p.jpg', class_name_mapping=inv_name_mapping_dict)
# Out:
# Model prediction: planes
